# %%
import numpy as np
import matplotlib.pyplot as plt

import nengo
import nengo.spa as spa
from nengo.utils.compat import OrderedDict
from nengo.utils.distributions import Uniform, UniformHypersphere
from nengo.networks.associative import AutoAssociative, HeteroAssociative

# %%
from collections import defaultdict

states = {
    'INIT': 'graph_key=v_0, queue_head=v_0, queue_tail=v_0, queue_learning=-1',
    'IF': 'queue_key=graph_edge',
    'IN_Q': 'temp=graph_next',
    'LOOK_G': 'graph_key=temp',
    'NOTIN_Q': 'queue_key=queue_tail, queue_value=graph_edge, queue_learning=1',
    'ADDED_Q': 'queue_tail=graph_edge, queue_learning=-1, temp=graph_next',
    'END_G': 'queue_key=queue_head',
    'NEXT_Q': 'queue_head=queue_output, queue_key=queue_output',
}

transitions = {
    ('INIT', 'IF') : None,
    ('IF', 'IN_Q') : 'dot(queue_has_key, 1)',
    ('IF', 'NOTIN_Q') : '0.8',
    ('IF', 'END_G') : 'dot(queue_key, NULL)',
    ('IN_Q', 'LOOK_G') : None,
    ('NOTIN_Q', 'NOTIN_Q') : '0.8',
    ('NOTIN_Q', 'ADDED_Q') : 'dot(queue_has_key, 1)',
    ('ADDED_Q', 'LOOK_G') : None,
    ('LOOK_G', 'IF') : None,
    ('END_G', 'NEXT_Q') : None,
    ('END_G', 'IF') : None,
}

def dfa_to_actions(states, transitions, state_in='clean_state', state_out='noisy_state', weight=0.5):
    action_matches = {}
    action_effects = {}
    
    if not (0 < weight < 1):
        raise ValueError("weight (%s) must be in range (0, 1)" % weight)
    r_weight = 1 - weight
    
    for (pre, post), utility in transitions.iteritems():
        if utility is None:
            utility = '1.0'
        transition_name = '%s_TO_%s' % (pre, post)
        action_matches[transition_name] = '%s*dot(%s, F_%s) + %s*(%s)' % (
            weight, state_in, post, r_weight, utility)
        action_effects[transition_name] = '%s=%s' % (state_out, post)
    
    for post, effect in states.iteritems():        
        action_matches[post] = 'dot(%s, %s)' % (state_in, post)
        action_effects[post] = '%s, %s=%s' % (effect, state_out, post)
        
        all_effects = effect.split(',')
        matches = []
        for subeffect in all_effects:
            lvalue, rvalue = subeffect.split('=', 1)
            matches.append('dot(%s, %s)' % (lvalue.strip(), rvalue.strip()))
        done_effect_match = '%s*dot(%s, %s) + %s*(%s)' % (
            weight, state_in, post, r_weight / len(all_effects), ' + '.join(matches))
        
        action_matches['F_%s' % post] = done_effect_match
        action_effects['F_%s' % post] = '%s=F_%s' % (state_out, post)

    actions = {}
    for name in action_matches:
        actions[name] = '%s  -->  %s' % (action_matches[name], action_effects[name])
    
    return actions

# %%
class BFS(spa.SPA):

    def __init__(self, graph, dimensions, neurons_per_item=500, dimensions_state=32):
        super(BFS, self).__init__()
        
        num_vertices = len(graph)
        
        # Put the graph into a static Dict
        initial_keys = []
        initial_values = []
        graph_vocab = self.get_default_vocab(dimensions)
        for i, adj_list in enumerate(graph):
            for num, j in enumerate(adj_list):
                if not (0 <= j < num_vertices):
                    raise ValueError("Edge %d->%d out of range" % (i, j))
                key = 'V_%d' % i if num == 0 else 'P_%d_%d' % (i, num)
                next_key = 'P_%d_%d' % (i, num + 1) if num != len(adj_list) - 1 else 'NULL' 
                initial_keys.append(graph_vocab.parse(key).v)
                initial_values.append(graph_vocab.parse('EDGE*V_%d+NEXT*%s' % (j, next_key)).v)
            #if not len(adj_list):
            #    initial_keys.append(graph_vocab.parse('V_%d' % i).v)
            #    initial_values.append('NULL')
        
        self.graph = AutoAssociative(
            nengo.LIF(neurons_per_item*len(initial_keys)), len(initial_keys),
            initial_keys=initial_keys, initial_values=initial_values)
        
        # Interface with the graph using SPA blocks
        self.graph_key = spa.Memory(dimensions=dimensions)
        self.graph_output = spa.Buffer(dimensions=dimensions)
        nengo.Connection(self.graph_key.state.output, self.graph.key)
        nengo.Connection(self.graph.output, self.graph_output.state.input, filter=None)
        self.graph_edge = spa.Buffer(dimensions=dimensions)
        self.graph_next = spa.Buffer(dimensions=dimensions)
        
        # Create a queue using a Dict and interface with SPA blocks
        self.queue = AutoAssociative(
            nengo.LIF(neurons_per_item*num_vertices), num_vertices, dimensions, dimensions,
            initial_keys=[graph_vocab.parse('V_0').v], initial_values=[graph_vocab.parse('V_0').v])
        self.queue_key = spa.Memory(dimensions=dimensions)
        self.queue_value = spa.Memory(dimensions=dimensions)
        self.queue_learning = spa.Memory(dimensions=1, subdimensions=1)
        self.queue_output = spa.Buffer(dimensions=dimensions)
        self.queue_has_key = spa.Buffer(dimensions=1, subdimensions=1)
        nengo.Connection(self.queue_key.state.output, self.queue.key)
        nengo.Connection(self.queue_value.state.output, self.queue.value)
        nengo.Connection(self.queue_learning.state.output, self.queue.learning)
        nengo.Connection(self.queue.output, self.queue_output.state.input, filter=None)
        nengo.Connection(self.queue.has_key, self.queue_has_key.state.input, filter=None)
        
        # Control flow
        actions = dfa_to_actions(states, transitions)
        for name, action in actions.items():
            print action
        actions = spa.Actions(**actions)
        cortical_actions = spa.Actions('graph_edge=graph_output*~EDGE',
                                       'graph_next=graph_output*~NEXT')
        self.noisy_state = spa.Memory(dimensions=dimensions_state)
        self.clean_state = spa.Buffer(dimensions=dimensions_state)
        self.v_0 = spa.Buffer(dimensions=dimensions)
        self.temp = spa.Memory(dimensions=dimensions)
        self.queue_head = spa.Memory(dimensions=dimensions)
        self.queue_tail = spa.Memory(dimensions=dimensions)
        self.bg = spa.BasalGanglia(actions=actions)
        self.thal = spa.Thalamus(self.bg)
        self.cortical = spa.Cortical(cortical_actions)
        
        # State cleanup
        state_vocab = self.get_module_output('noisy_state')[1].vectors
        self.state_cleanup = HeteroAssociative(
            nengo.LIF(2000), len(state_vocab), initial_keys=state_vocab)
        nengo.Connection(self.noisy_state.state.output, self.state_cleanup.key)
        nengo.Connection(self.state_cleanup.output, self.clean_state.state.input)
        
        # Initialize starting vertex and state
        self.input_vertex = spa.Input(v_0=lambda t: 'V_0')
        self.input_state = spa.Input(noisy_state=lambda t: 'INIT' if t < 0.2 else '0')

# %%
graph = [[1, 2],
         [0, 3],
         [0],
         [0, 1, 2]]

d = 64

model = nengo.Network()
with model:
    bfs = BFS(graph, d)

    modules = ('v_0', 'noisy_state', 'clean_state', 'graph_key', 'graph_edge', 'graph_next',
               'queue_head', 'queue_tail', 'queue_key', 'queue_value', 'queue_learning',
               'queue_output', 'queue_has_key', 'temp')
    module_probes = OrderedDict([
        (module, nengo.Probe(bfs.get_module_output(module)[0], filter=0.03))
        for module in modules])
    actions_probe = nengo.Probe(bfs.thal.actions.output, filter=0.03)
    utilities_probe = nengo.Probe(bfs.bg.input, filter=0.03)
# Out:
# dot(clean_state, NEXT_Q)  -->  queue_head=queue_output, queue_key=queue_output, noisy_state=NEXT_Q
# 0.5*dot(clean_state, F_LOOK_G) + 0.5*(1.0)  -->  noisy_state=LOOK_G
# dot(clean_state, NOTIN_Q)  -->  queue_key=queue_tail, queue_value=graph_edge, queue_learning=1, noisy_state=NOTIN_Q
# 0.5*dot(clean_state, LOOK_G) + 0.5*(dot(graph_key, temp))  -->  noisy_state=F_LOOK_G
# dot(clean_state, END_G)  -->  queue_key=queue_head, noisy_state=END_G
# 0.5*dot(clean_state, INIT) + 0.125*(dot(graph_key, v_0) + dot(queue_head, v_0) + dot(queue_tail, v_0) + dot(queue_learning, -1))  -->  noisy_state=F_INIT
# 0.5*dot(clean_state, IN_Q) + 0.5*(dot(temp, graph_next))  -->  noisy_state=F_IN_Q
# dot(clean_state, INIT)  -->  graph_key=v_0, queue_head=v_0, queue_tail=v_0, queue_learning=-1, noisy_state=INIT
# 0.5*dot(clean_state, F_IF) + 0.5*(1.0)  -->  noisy_state=IF
# 0.5*dot(clean_state, F_IN_Q) + 0.5*(dot(queue_has_key, 1))  -->  noisy_state=IN_Q
# 0.5*dot(clean_state, END_G) + 0.5*(dot(queue_key, queue_head))  -->  noisy_state=F_END_G
# 0.5*dot(clean_state, NEXT_Q) + 0.25*(dot(queue_head, queue_output) + dot(queue_key, queue_output))  -->  noisy_state=F_NEXT_Q
# 0.5*dot(clean_state, IF) + 0.5*(dot(queue_key, graph_edge))  -->  noisy_state=F_IF
# dot(clean_state, IN_Q)  -->  temp=graph_next, noisy_state=IN_Q
# dot(clean_state, IF)  -->  queue_key=graph_edge, noisy_state=IF
# 0.5*dot(clean_state, NOTIN_Q) + 0.166666666667*(dot(queue_key, queue_tail) + dot(queue_value, graph_edge) + dot(queue_learning, 1))  -->  noisy_state=F_NOTIN_Q
# 0.5*dot(clean_state, F_NOTIN_Q) + 0.5*(0.8)  -->  noisy_state=NOTIN_Q
# 0.5*dot(clean_state, F_IF) + 0.5*(1.0)  -->  noisy_state=IF
# dot(clean_state, ADDED_Q)  -->  queue_tail=graph_edge, queue_learning=-1, temp=graph_next, noisy_state=ADDED_Q
# 0.5*dot(clean_state, ADDED_Q) + 0.166666666667*(dot(queue_tail, graph_edge) + dot(queue_learning, -1) + dot(temp, graph_next))  -->  noisy_state=F_ADDED_Q
# 0.5*dot(clean_state, F_LOOK_G) + 0.5*(1.0)  -->  noisy_state=LOOK_G
# 0.5*dot(clean_state, F_END_G) + 0.5*(dot(queue_key, NULL))  -->  noisy_state=END_G
# dot(clean_state, LOOK_G)  -->  graph_key=temp, noisy_state=LOOK_G
# 0.5*dot(clean_state, F_ADDED_Q) + 0.5*(dot(queue_has_key, 1))  -->  noisy_state=ADDED_Q
# 0.5*dot(clean_state, F_IF) + 0.5*(1.0)  -->  noisy_state=IF
# 0.5*dot(clean_state, F_NEXT_Q) + 0.5*(1.0)  -->  noisy_state=NEXT_Q
# 0.5*dot(clean_state, F_NOTIN_Q) + 0.5*(0.8)  -->  noisy_state=NOTIN_Q
# Warning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=9)
# Warning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=13)
# Warning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=14)
# Warning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=15)

# %%
sim = nengo.Simulator(model)
sim.run(0.5)

# %%
plt.figure(figsize=(10, 10))
plt.title("Utilities")
plt.plot(sim.trange(), sim.data[utilities_probe])
plt.legend([action.name for action in bfs.bg.actions.actions])

plt.figure(figsize=(10, 10))
plt.title("Rules")
plt.plot(sim.trange(), sim.data[actions_probe])
plt.legend([action.name for action in bfs.bg.actions.actions])

for module, probe in module_probes.items():
    plt.figure(figsize=(10, 10))
    plt.title(module)
    if sim.data[probe].shape[1] == 1:
        plt.plot(sim.trange(), sim.data[probe])
    else:
        plt.plot(sim.trange(), np.dot(sim.data[probe], bfs.get_module_output(module)[1].vectors.T))
        plt.legend(bfs.get_module_output(module)[1].keys, fontsize='small')
