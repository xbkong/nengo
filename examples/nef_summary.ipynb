# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import nengo
# %load_ext nengo.ipynb
from nengo.dists import Uniform
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="2115821212" href="javascript:toggle_input_2115821212()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2115821212;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2115821212 = document.getElementById("2115821212");
#                 var cell = link_2115821212;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2115821212;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_2115821212 = cell.children[i];
#                 }
#                 input_2115821212.style.display = "none"; // hide
#
#                 toggle_input_2115821212 = function() {
#                     if (input_2115821212.style.display == "none") {
#                         input_2115821212.style.display = ""; // show
#                         link_2115821212.innerHTML = "Hide Input";
#                     } else {
#                         input_2115821212.style.display = "none"; // hide
#                         link_2115821212.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2115821212 = $("a[id='2115821212']");
#                 var cell_2115821212 = link_2115821212.parents("div.cell:first");
#                 var input_2115821212 = cell_2115821212.children("div.input");
#                 input_2115821212.hide();
#
#                 toggle_input_2115821212 = function() {
#                     if (input_2115821212.is(':hidden')) {
#                         input_2115821212.slideDown();
#                         link_2115821212[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2115821212.slideUp();
#                         link_2115821212[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Introduction
# The Neural Engineering Framework (NEF) is the set of theoretical methods that are used in Nengo for constructing neural models.  The NEF is based on <a href="http://www.amazon.com/gp/product/0262550601">Eliasmith & Anderson's (2003) book</a> from MIT Press. This notebook introduces the three main principles discussed in that book and implemented in Nengo.

# %% [markdown]
# # Principle 1: Representation
#
# ## Encoding
#
# Neural populations represent time-varying signals through their spiking responses. A signal is a vector of real numbers of arbitrary length. This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="2142486466" href="javascript:toggle_input_2142486466()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2142486466;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2142486466 = document.getElementById("2142486466");
#                 var cell = link_2142486466;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2142486466;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_2142486466 = cell.children[i];
#                 }
#                 input_2142486466.style.display = "none"; // hide
#
#                 toggle_input_2142486466 = function() {
#                     if (input_2142486466.style.display == "none") {
#                         input_2142486466.style.display = ""; // show
#                         link_2142486466.innerHTML = "Hide Input";
#                     } else {
#                         input_2142486466.style.display = "none"; // hide
#                         link_2142486466.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2142486466 = $("a[id='2142486466']");
#                 var cell_2142486466 = link_2142486466.parents("div.cell:first");
#                 var input_2142486466 = cell_2142486466.children("div.input");
#                 input_2142486466.hide();
#
#                 toggle_input_2142486466 = function() {
#                     if (input_2142486466.is(':hidden')) {
#                         input_2142486466.slideDown();
#                         link_2142486466[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2142486466.slideUp();
#                         link_2142486466[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations based on each neuron's *tuning curve* (which is similar to the I-F (current-frequency) curve, if you're familiar with that).
#
# The tuning curve describes how much a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="83531254" href="javascript:toggle_input_83531254()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_83531254;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_83531254 = document.getElementById("83531254");
#                 var cell = link_83531254;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_83531254;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_83531254 = cell.children[i];
#                 }
#                 input_83531254.style.display = "none"; // hide
#
#                 toggle_input_83531254 = function() {
#                     if (input_83531254.style.display == "none") {
#                         input_83531254.style.display = ""; // show
#                         link_83531254.innerHTML = "Hide Input";
#                     } else {
#                         input_83531254.style.display = "none"; // hide
#                         link_83531254.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_83531254 = $("a[id='83531254']");
#                 var cell_83531254 = link_83531254.parents("div.cell:first");
#                 var input_83531254 = cell_83531254.children("div.input");
#                 input_83531254.hide();
#
#                 toggle_input_83531254 = function() {
#                     if (input_83531254.is(':hidden')) {
#                         input_83531254.slideDown();
#                         link_83531254[0].innerHTML = "Hide Input";
#                     } else {
#                         input_83531254.slideUp();
#                         link_83531254[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="1060937975" href="javascript:toggle_input_1060937975()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1060937975;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1060937975 = document.getElementById("1060937975");
#                 var cell = link_1060937975;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1060937975;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1060937975 = cell.children[i];
#                 }
#                 input_1060937975.style.display = "none"; // hide
#
#                 toggle_input_1060937975 = function() {
#                     if (input_1060937975.style.display == "none") {
#                         input_1060937975.style.display = ""; // show
#                         link_1060937975.innerHTML = "Hide Input";
#                     } else {
#                         input_1060937975.style.display = "none"; // hide
#                         link_1060937975.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1060937975 = $("a[id='1060937975']");
#                 var cell_1060937975 = link_1060937975.parents("div.cell:first");
#                 var input_1060937975 = cell_1060937975.children("div.input");
#                 input_1060937975.hide();
#
#                 toggle_input_1060937975 = function() {
#                     if (input_1060937975.is(':hidden')) {
#                         input_1060937975.slideDown();
#                         link_1060937975[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1060937975.slideUp();
#                         link_1060937975[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Decoding
#
# We can estimate the input signal originally encoded by decoding the pattern of spikes. To do this, we first filter the spike train with a temporal filter that accounts for postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons));
hide_input()
# Out:
#         <a id="857326623" href="javascript:toggle_input_857326623()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_857326623;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_857326623 = document.getElementById("857326623");
#                 var cell = link_857326623;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_857326623;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_857326623 = cell.children[i];
#                 }
#                 input_857326623.style.display = "none"; // hide
#
#                 toggle_input_857326623 = function() {
#                     if (input_857326623.style.display == "none") {
#                         input_857326623.style.display = ""; // show
#                         link_857326623.innerHTML = "Hide Input";
#                     } else {
#                         input_857326623.style.display = "none"; // hide
#                         link_857326623.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_857326623 = $("a[id='857326623']");
#                 var cell_857326623 = link_857326623.parents("div.cell:first");
#                 var input_857326623 = cell_857326623.children("div.input");
#                 input_857326623.hide();
#
#                 toggle_input_857326623 = function() {
#                     if (input_857326623.is(':hidden')) {
#                         input_857326623.slideDown();
#                         link_857326623[0].innerHTML = "Hide Input";
#                     } else {
#                         input_857326623.slideUp();
#                         link_857326623[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains with decoding weights and sum them together to give an estimate of the input based on the spikes.
#
# The decoding weights are determined by minimizing the squared difference between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1447155786" href="javascript:toggle_input_1447155786()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1447155786;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1447155786 = document.getElementById("1447155786");
#                 var cell = link_1447155786;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1447155786;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1447155786 = cell.children[i];
#                 }
#                 input_1447155786.style.display = "none"; // hide
#
#                 toggle_input_1447155786 = function() {
#                     if (input_1447155786.style.display == "none") {
#                         input_1447155786.style.display = ""; // show
#                         link_1447155786.innerHTML = "Hide Input";
#                     } else {
#                         input_1447155786.style.display = "none"; // hide
#                         link_1447155786.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1447155786 = $("a[id='1447155786']");
#                 var cell_1447155786 = link_1447155786.parents("div.cell:first");
#                 var input_1447155786 = cell_1447155786.children("div.input");
#                 input_1447155786.hide();
#
#                 toggle_input_1447155786 = function() {
#                     if (input_1447155786.is(':hidden')) {
#                         input_1447155786.slideDown();
#                         link_1447155786[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1447155786.slideUp();
#                         link_1447155786[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="104063053" href="javascript:toggle_input_104063053()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_104063053;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_104063053 = document.getElementById("104063053");
#                 var cell = link_104063053;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_104063053;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_104063053 = cell.children[i];
#                 }
#                 input_104063053.style.display = "none"; // hide
#
#                 toggle_input_104063053 = function() {
#                     if (input_104063053.style.display == "none") {
#                         input_104063053.style.display = ""; // show
#                         link_104063053.innerHTML = "Hide Input";
#                     } else {
#                         input_104063053.style.display = "none"; // hide
#                         link_104063053.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_104063053 = $("a[id='104063053']");
#                 var cell_104063053 = link_104063053.parents("div.cell:first");
#                 var input_104063053 = cell_104063053.children("div.input");
#                 input_104063053.hide();
#
#                 toggle_input_104063053 = function() {
#                     if (input_104063053.is(':hidden')) {
#                         input_104063053.slideDown();
#                         link_104063053[0].innerHTML = "Hide Input";
#                     } else {
#                         input_104063053.slideUp();
#                         link_104063053[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
from nengo.processes import WhiteSignal

model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="1955225772" href="javascript:toggle_input_1955225772()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1955225772;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1955225772 = document.getElementById("1955225772");
#                 var cell = link_1955225772;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1955225772;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1955225772 = cell.children[i];
#                 }
#                 input_1955225772.style.display = "none"; // hide
#
#                 toggle_input_1955225772 = function() {
#                     if (input_1955225772.style.display == "none") {
#                         input_1955225772.style.display = ""; // show
#                         link_1955225772.innerHTML = "Hide Input";
#                     } else {
#                         input_1955225772.style.display = "none"; // hide
#                         link_1955225772.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1955225772 = $("a[id='1955225772']");
#                 var cell_1955225772 = link_1955225772.parents("div.cell:first");
#                 var input_1955225772 = cell_1955225772.children("div.input");
#                 input_1955225772.hide();
#
#                 toggle_input_1955225772 = function() {
#                     if (input_1955225772.is(':hidden')) {
#                         input_1955225772.slideDown();
#                         link_1955225772[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1955225772.slideUp();
#                         link_1955225772[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time, and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal, not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="1883013630" href="javascript:toggle_input_1883013630()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1883013630;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1883013630 = document.getElementById("1883013630");
#                 var cell = link_1883013630;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1883013630;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1883013630 = cell.children[i];
#                 }
#                 input_1883013630.style.display = "none"; // hide
#
#                 toggle_input_1883013630 = function() {
#                     if (input_1883013630.style.display == "none") {
#                         input_1883013630.style.display = ""; // show
#                         link_1883013630.innerHTML = "Hide Input";
#                     } else {
#                         input_1883013630.style.display = "none"; // hide
#                         link_1883013630.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1883013630 = $("a[id='1883013630']");
#                 var cell_1883013630 = link_1883013630.parents("div.cell:first");
#                 var input_1883013630 = cell_1883013630.children("div.input");
#                 input_1883013630.hide();
#
#                 toggle_input_1883013630 = function() {
#                     if (input_1883013630.is(':hidden')) {
#                         input_1883013630.slideDown();
#                         link_1883013630[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1883013630.slideUp();
#                         link_1883013630[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same. The only difference is how we're interpreting those spikes. We told Nengo to compute a new set of decoders that estimate the function $x^2$.
#
# In general, the transformation principle determines how we can decode spike trains to compute linear and nonlinear transformations of signals encoded in a population of neurons. We can then project those transformed signals into another population, and repeat the process.  Essentially, this provides a means of computing the neural connection weights to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="931735091" href="javascript:toggle_input_931735091()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_931735091;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_931735091 = document.getElementById("931735091");
#                 var cell = link_931735091;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_931735091;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_931735091 = cell.children[i];
#                 }
#                 input_931735091.style.display = "none"; // hide
#
#                 toggle_input_931735091 = function() {
#                     if (input_931735091.style.display == "none") {
#                         input_931735091.style.display = ""; // show
#                         link_931735091.innerHTML = "Hide Input";
#                     } else {
#                         input_931735091.style.display = "none"; // hide
#                         link_931735091.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_931735091 = $("a[id='931735091']");
#                 var cell_931735091 = link_931735091.parents("div.cell:first");
#                 var input_931735091 = cell_931735091.children("div.input");
#                 input_931735091.hide();
#
#                 toggle_input_931735091 = function() {
#                     if (input_931735091.is(':hidden')) {
#                         input_931735091.slideDown();
#                         link_931735091[0].innerHTML = "Hide Input";
#                     } else {
#                         input_931735091.slideUp();
#                         link_931735091[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal involve solving for the usual decoders, and scaling those decoding weights. Let us flip this sine wave upside down as it is transmitted between two populations (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
# /home/travis/build/nengo/nengo/nengo/builder/optimizer.py:636: UserWarning: Skipping some optimization steps because SciPy is not installed. Installing SciPy may result in faster simulations.
#   warnings.warn("Skipping some optimization steps because SciPy is "
#         <a id="1078818722" href="javascript:toggle_input_1078818722()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1078818722;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1078818722 = document.getElementById("1078818722");
#                 var cell = link_1078818722;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1078818722;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1078818722 = cell.children[i];
#                 }
#                 input_1078818722.style.display = "none"; // hide
#
#                 toggle_input_1078818722 = function() {
#                     if (input_1078818722.style.display == "none") {
#                         input_1078818722.style.display = ""; // show
#                         link_1078818722.innerHTML = "Hide Input";
#                     } else {
#                         input_1078818722.style.display = "none"; // hide
#                         link_1078818722.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1078818722 = $("a[id='1078818722']");
#                 var cell_1078818722 = link_1078818722.parents("div.cell:first");
#                 var input_1078818722 = cell_1078818722.children("div.input");
#                 input_1078818722.hide();
#
#                 toggle_input_1078818722 = function() {
#                     if (input_1078818722.is(':hidden')) {
#                         input_1078818722.slideDown();
#                         link_1078818722[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1078818722.slideUp();
#                         link_1078818722[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve solving for a new set of decoding weights. Let us add a third population connected to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="189652053" href="javascript:toggle_input_189652053()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_189652053;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_189652053 = document.getElementById("189652053");
#                 var cell = link_189652053;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_189652053;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_189652053 = cell.children[i];
#                 }
#                 input_189652053.style.display = "none"; // hide
#
#                 toggle_input_189652053 = function() {
#                     if (input_189652053.style.display == "none") {
#                         input_189652053.style.display = ""; // show
#                         link_189652053.innerHTML = "Hide Input";
#                     } else {
#                         input_189652053.style.display = "none"; // hide
#                         link_189652053.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_189652053 = $("a[id='189652053']");
#                 var cell_189652053 = link_189652053.parents("div.cell:first");
#                 var input_189652053 = cell_189652053.children("div.input");
#                 input_189652053.hide();
#
#                 toggle_input_189652053 = function() {
#                     if (input_189652053.is(':hidden')) {
#                         input_189652053.slideDown();
#                         link_189652053[0].innerHTML = "Hide Input";
#                     } else {
#                         input_189652053.slideUp();
#                         link_189652053[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 3: Dynamics
#
# So far, we have been considering the values represented by ensembles as generic "signals." However, if we think of them instead as state variables in a dynamical system, then we can apply the methods of control theory or dynamic systems theory to brain models.  Nengo automatically translates from standard dynamical systems descriptions to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics, we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator implemented using this third principle. It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$');
hide_input()
# Out:
#         <a id="320548176" href="javascript:toggle_input_320548176()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_320548176;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_320548176 = document.getElementById("320548176");
#                 var cell = link_320548176;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_320548176;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_320548176 = cell.children[i];
#                 }
#                 input_320548176.style.display = "none"; // hide
#
#                 toggle_input_320548176 = function() {
#                     if (input_320548176.style.display == "none") {
#                         input_320548176.style.display = ""; // show
#                         link_320548176.innerHTML = "Hide Input";
#                     } else {
#                         input_320548176.style.display = "none"; // hide
#                         link_320548176.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_320548176 = $("a[id='320548176']");
#                 var cell_320548176 = link_320548176.parents("div.cell:first");
#                 var input_320548176 = cell_320548176.children("div.input");
#                 input_320548176.hide();
#
#                 toggle_input_320548176 = function() {
#                     if (input_320548176.is(':hidden')) {
#                         input_320548176.slideDown();
#                         link_320548176[0].innerHTML = "Hide Input";
#                     } else {
#                         input_320548176.slideUp();
#                         link_320548176[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
